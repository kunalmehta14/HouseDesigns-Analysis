# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %%
closet_designs = tf.keras.utils.image_dataset_from_directory('/opt/JupyterNotebooks/home-styles/Storage & Closet/interior-designs', batch_size=64, label_mode='categorical')
# Out:
# Found 19316 files belonging to 18 classes.

# %%
closet_class_names = closet_designs.class_names
for i, class_name in enumerate(closet_class_names):
    print(f"Class name: {class_name}, Integer label: {i}")
# Out:
# Class name: Asian, Integer label: 0
# Class name: Coastal, Integer label: 1
# Class name: Contemporary, Integer label: 2
# Class name: Craftsman, Integer label: 3
# Class name: Eclectic, Integer label: 4
# Class name: Farmhouse, Integer label: 5
# Class name: Industrial, Integer label: 6
# Class name: Mediterranean, Integer label: 7
# Class name: Mid-Century-Modern, Integer label: 8
# Class name: Modern, Integer label: 9
# Class name: Rustic, Integer label: 10
# Class name: Scandinavian, Integer label: 11
# Class name: Shabby-Chic, Integer label: 12
# Class name: Southwestern, Integer label: 13
# Class name: Traditional, Integer label: 14
# Class name: Transitional, Integer label: 15
# Class name: Tropical, Integer label: 16
# Class name: Victorian, Integer label: 17

# %%
import numpy as np

data_iterator = closet_designs.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
#Normalization of the images
closet_designs = closet_designs.map(lambda x, y: (x / 255.0, y))

# %%
train_size = int(len(closet_designs)*.8)
val_size = int(len(closet_designs)*.2)

train = closet_designs.take(train_size)
val = closet_designs.skip(train_size).take(val_size)

# %%
def image_augmentation(image, label):
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_hue(image, 0.2)
    image = tf.image.random_saturation(image, 0.5, 1.0)
    return image, label

# %%
augmented_train = train.map(image_augmentation)

# %%
# Visualizing the augmented training dataset
for images, labels in augmented_train.take(2):
    for i in range(min(5, len(images))):
        image = images[i].numpy() 
        label = labels[i].numpy()
        plt.subplots(figsize=(3,3))
        plt.imshow(image)
        plt.title(f'Label: {label}')
        plt.axis('off')  # Hide axes
        plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def plot_history(history):
    # Figure Configuration to show two subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))
    # Plot one to visualize the loss from the history
    ax1.plot(history.history['loss'], label='loss')
    ax1.plot(history.history['val_loss'], label='val_loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Binary Crossentropy')
    ax1.grid(True)
    ax1.legend(['Loss', 'Val_Loss'])
    # Plot two to visualize the accuracy from the history
    ax2.plot(history.history['accuracy'], label='accuracy')
    ax2.plot(history.history['val_accuracy'], label='val_accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.grid(True)
    ax2.legend(['Accuracy', 'Val_Accuracy'])
    plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
def train_model(filter_1, filter_2, filter_3, kernel, num_of_epochs, training_dataset, validation_dataset):
    model = Sequential()
    model.add(Conv2D(filter_1, (kernel,kernel), 1, activation='relu', input_shape=(256,256,3)))
    model.add(MaxPooling2D())
    model.add(Conv2D(filter_2, (kernel,kernel), 1, activation='relu'))
    model.add(MaxPooling2D())
    model.add(Conv2D(filter_3, (kernel,kernel), 1, activation='relu'))
    model.add(MaxPooling2D())
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(18, activation='softmax'))
    model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])
    model.summary()
    logdir = 'logs'
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
    history = model.fit(training_dataset, epochs=num_of_epochs, validation_data=validation_dataset, callbacks=[tensorboard_callback])
    return model, history

# %%
model, history = train_model(64, 128, 128, 5, 7, augmented_train, val)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 252, 252, 64)   │         4,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 126, 126, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 122, 122, 128)  │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 61, 61, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 57, 57, 128)    │       409,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │    25,690,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 18)             │         4,626 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,314,514 (100.38 MB)
#  Trainable params: 26,314,514 (100.38 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/7
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 74s 297ms/step - accuracy: 0.1499 - loss: 0.2278 - val_accuracy: 0.1813 - val_loss: 0.1934
# Epoch 2/7
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 71s 294ms/step - accuracy: 0.1609 - loss: 0.1959 - val_accuracy: 0.1555 - val_loss: 0.1934
# Epoch 3/7
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.1747 - loss: 0.1945 - val_accuracy: 0.1763 - val_loss: 0.1933
# Epoch 4/7
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.1760 - loss: 0.1937 - val_accuracy: 0.1615 - val_loss: 0.1921
# Epoch 5/7
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 71s 294ms/step - accuracy: 0.1909 - loss: 0.1914 - val_accuracy: 0.1701 - val_loss: 0.1918
# Epoch 6/7
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 71s 294ms/step - accuracy: 0.2051 - loss: 0.1891 - val_accuracy: 0.1857 - val_loss: 0.1912
# Epoch 7/7
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.2136 - loss: 0.1867 - val_accuracy: 0.1852 - val_loss: 0.1914

# %%
plot_history(history)

# %%
model.save('/opt/JupyterNotebooks/house-styles-models/closet-style-classification-model.keras')
